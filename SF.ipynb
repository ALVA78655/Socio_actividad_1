# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga desde un archivo .xlsx sin indice
Credi= pd.read_excel('cuentas_credicel1.xlsx')
Credi
# Out:
#        folio       tag  folio_solicitud               fecha     marca  \
# 0          3  HDNAWQ3A               30 2021-11-12 19:00:05       ZTE
# 1          4  M418YNR4               33 2021-11-12 19:15:58  MOTOROLA
# 2          5  SZ7V3NZT               37 2021-11-13 14:13:08       ZTE
# 3          6  9I08UIQZ               38 2021-11-13 15:45:39       ZTE
# 4          7  JMF4LKYU               44 2021-11-13 16:10:15  MOTOROLA
# ...      ...       ...              ...                 ...       ...
# 22730  22967  92KQVRIX            96502 2023-04-18 18:45:00  Motorola
# 22731  22968  NWB2EA8J            96479 2023-04-18 18:46:53  Motorola
# 22732  22969  VDTRJ2W6            96442 2023-04-18 18:47:47   Samsung
# 22733  22970  PETLF56C            96536 2023-04-18 18:49:08   Samsung
# 22734  22971  2CI4N2WS            96534 2023-04-18 18:49:39   Samsung
#
#                              modelo plazo  precio  enganche  descuento  ...  \
# ...

# %%
valores_nulos=Credi.isnull().sum()
valores_nulos
# Out:
# folio                     0
# tag                       0
# folio_solicitud           0
# fecha                     0
# marca                     0
# modelo                    0
# plazo                     0
# precio                    0
# enganche                  0
# descuento                 0
# semana                    0
# monto_financiado          0
# costo_total               0
# monto_accesorios          0
# agente_venta              0
# dis_venta                 0
# status                    0
# fraude                    0
# empresa                  13
# inversion                 0
# pagos_realizados          0
# reautorizacion            0
# fecha_ultimo_pago      3356
# fecha_pago_proximo     3356
# status_cuenta          4197
# puntos                 3595
# riesgo                 2473
# porc_enganche          2473
# porc_tasa                 0
# score_buro                0
# razones_buro           4505
# semana_actual          4505
# codigo_postal           685
# ...

# %%
Credi["empresa"]=Credi["empresa"].fillna("Desconocido")

# %%
valores_nulos=Credi.isnull().sum()
valores_nulos
# Out:
# folio                     0
# tag                       0
# folio_solicitud           0
# fecha                     0
# marca                     0
# modelo                    0
# plazo                     0
# precio                    0
# enganche                  0
# descuento                 0
# semana                    0
# monto_financiado          0
# costo_total               0
# monto_accesorios          0
# agente_venta              0
# dis_venta                 0
# status                    0
# fraude                    0
# empresa                   0
# inversion                 0
# pagos_realizados          0
# reautorizacion            0
# fecha_ultimo_pago      3356
# fecha_pago_proximo     3356
# status_cuenta          4197
# puntos                 3595
# riesgo                 2473
# porc_enganche          2473
# porc_tasa                 0
# score_buro                0
# razones_buro           4505
# semana_actual          4505
# codigo_postal           685
# ...

# %%
Credi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22735 entries, 0 to 22734
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   folio               22735 non-null  int64
#  1   tag                 22735 non-null  object
#  2   folio_solicitud     22735 non-null  int64
#  3   fecha               22735 non-null  datetime64[ns]
#  4   marca               22735 non-null  object
#  5   modelo              22735 non-null  object
#  6   plazo               22735 non-null  object
#  7   precio              22735 non-null  float64
#  8   enganche            22735 non-null  float64
#  9   descuento           22735 non-null  float64
#  10  semana              22735 non-null  int64
#  11  monto_financiado    22735 non-null  float64
#  12  costo_total         22735 non-null  int64
#  13  monto_accesorios    22735 non-null  float64
#  14  agente_venta        22735 non-null  object
# ...

# %%
Credi["fecha_ultimo_pago"]=Credi["fecha_ultimo_pago"].fillna("desconocido")

# %%
valores_nulos=Credi.isnull().sum()
valores_nulos
# Out:
# folio                     0
# tag                       0
# folio_solicitud           0
# fecha                     0
# marca                     0
# modelo                    0
# plazo                     0
# precio                    0
# enganche                  0
# descuento                 0
# semana                    0
# monto_financiado          0
# costo_total               0
# monto_accesorios          0
# agente_venta              0
# dis_venta                 0
# status                    0
# fraude                    0
# empresa                   0
# inversion                 0
# pagos_realizados          0
# reautorizacion            0
# fecha_ultimo_pago         0
# fecha_pago_proximo     3356
# status_cuenta          4197
# puntos                 3595
# riesgo                 2473
# porc_enganche          2473
# porc_tasa                 0
# score_buro                0
# razones_buro           4505
# semana_actual          4505
# codigo_postal           685
# ...

# %%
Credi["fecha_pago_proximo"]=Credi["fecha_pago_proximo"].fillna("desconocido")

# %%
valores_nulos=Credi.isnull().sum()
valores_nulos
# Out:
# folio                     0
# tag                       0
# folio_solicitud           0
# fecha                     0
# marca                     0
# modelo                    0
# plazo                     0
# precio                    0
# enganche                  0
# descuento                 0
# semana                    0
# monto_financiado          0
# costo_total               0
# monto_accesorios          0
# agente_venta              0
# dis_venta                 0
# status                    0
# fraude                    0
# empresa                   0
# inversion                 0
# pagos_realizados          0
# reautorizacion            0
# fecha_ultimo_pago         0
# fecha_pago_proximo        0
# status_cuenta          4197
# puntos                 3595
# riesgo                 2473
# porc_enganche          2473
# porc_tasa                 0
# score_buro                0
# razones_buro           4505
# semana_actual          4505
# codigo_postal           685
# ...

# %%
Credi["status_cuenta"]=Credi["status_cuenta"].fillna("No determinado")

# %%
valores_nulos=Credi.isnull().sum()
valores_nulos
# Out:
# folio                     0
# tag                       0
# folio_solicitud           0
# fecha                     0
# marca                     0
# modelo                    0
# plazo                     0
# precio                    0
# enganche                  0
# descuento                 0
# semana                    0
# monto_financiado          0
# costo_total               0
# monto_accesorios          0
# agente_venta              0
# dis_venta                 0
# status                    0
# fraude                    0
# empresa                   0
# inversion                 0
# pagos_realizados          0
# reautorizacion            0
# fecha_ultimo_pago         0
# fecha_pago_proximo        0
# status_cuenta             0
# puntos                 3595
# riesgo                 2473
# porc_enganche          2473
# porc_tasa                 0
# score_buro                0
# razones_buro           4505
# semana_actual          4505
# codigo_postal           685
# ...

# %%
Credi["puntos"]=Credi["puntos"].fillna(Credi["puntos"].median())

# %%
valores_nulos=Credi.isnull().sum()
valores_nulos
# Out:
# folio                     0
# tag                       0
# folio_solicitud           0
# fecha                     0
# marca                     0
# modelo                    0
# plazo                     0
# precio                    0
# enganche                  0
# descuento                 0
# semana                    0
# monto_financiado          0
# costo_total               0
# monto_accesorios          0
# agente_venta              0
# dis_venta                 0
# status                    0
# fraude                    0
# empresa                   0
# inversion                 0
# pagos_realizados          0
# reautorizacion            0
# fecha_ultimo_pago         0
# fecha_pago_proximo        0
# status_cuenta             0
# puntos                    0
# riesgo                 2473
# porc_enganche          2473
# porc_tasa                 0
# score_buro                0
# razones_buro           4505
# semana_actual          4505
# codigo_postal           685
# ...

# %%
Credi["riesgo"]=Credi["riesgo"].fillna(Credi["riesgo"].median())

# %%
valores_nulos=Credi.isnull().sum()
valores_nulos
# Out:
# folio                     0
# tag                       0
# folio_solicitud           0
# fecha                     0
# marca                     0
# modelo                    0
# plazo                     0
# precio                    0
# enganche                  0
# descuento                 0
# semana                    0
# monto_financiado          0
# costo_total               0
# monto_accesorios          0
# agente_venta              0
# dis_venta                 0
# status                    0
# fraude                    0
# empresa                   0
# inversion                 0
# pagos_realizados          0
# reautorizacion            0
# fecha_ultimo_pago         0
# fecha_pago_proximo        0
# status_cuenta             0
# puntos                    0
# riesgo                    0
# porc_enganche          2473
# porc_tasa                 0
# score_buro                0
# razones_buro           4505
# semana_actual          4505
# codigo_postal           685
# ...

# %%
Credi=Credi.drop('Unnamed: 33', axis=1)

# %%
valores_nulos=Credi.isnull().sum()
valores_nulos
# Out:
# folio                    0
# tag                      0
# folio_solicitud          0
# fecha                    0
# marca                    0
# modelo                   0
# plazo                    0
# precio                   0
# enganche                 0
# descuento                0
# semana                   0
# monto_financiado         0
# costo_total              0
# monto_accesorios         0
# agente_venta             0
# dis_venta                0
# status                   0
# fraude                   0
# empresa                  0
# inversion                0
# pagos_realizados         0
# reautorizacion           0
# fecha_ultimo_pago        0
# fecha_pago_proximo       0
# status_cuenta            0
# puntos                   0
# riesgo                   0
# porc_enganche         2473
# porc_tasa                0
# score_buro               0
# razones_buro          4505
# semana_actual         4505
# codigo_postal          685
# dtype: int64

# %%
Credi["porc_enganche"]=Credi['porc_enganche'].fillna('0')

# %%
valores_nulos=Credi.isnull().sum()
valores_nulos
# Out:
# folio                    0
# tag                      0
# folio_solicitud          0
# fecha                    0
# marca                    0
# modelo                   0
# plazo                    0
# precio                   0
# enganche                 0
# descuento                0
# semana                   0
# monto_financiado         0
# costo_total              0
# monto_accesorios         0
# agente_venta             0
# dis_venta                0
# status                   0
# fraude                   0
# empresa                  0
# inversion                0
# pagos_realizados         0
# reautorizacion           0
# fecha_ultimo_pago        0
# fecha_pago_proximo       0
# status_cuenta            0
# puntos                   0
# riesgo                   0
# porc_enganche            0
# porc_tasa                0
# score_buro               0
# razones_buro          4505
# semana_actual         4505
# codigo_postal          685
# dtype: int64

# %%
Credi['razones_buro']=Credi['razones_buro'].fillna('Desconocido')

# %%
Credi['semana_actual']=Credi['semana_actual'].fillna('Faltante')

# %%
Credi['codigo_postal']=Credi['codigo_postal'].fillna('No identificable')

# %%
valores_nulos=Credi.isnull().sum()
valores_nulos
# Out:
# folio                 0
# tag                   0
# folio_solicitud       0
# fecha                 0
# marca                 0
# modelo                0
# plazo                 0
# precio                0
# enganche              0
# descuento             0
# semana                0
# monto_financiado      0
# costo_total           0
# monto_accesorios      0
# agente_venta          0
# dis_venta             0
# status                0
# fraude                0
# empresa               0
# inversion             0
# pagos_realizados      0
# reautorizacion        0
# fecha_ultimo_pago     0
# fecha_pago_proximo    0
# status_cuenta         0
# puntos                0
# riesgo                0
# porc_enganche         0
# porc_tasa             0
# score_buro            0
# razones_buro          0
# semana_actual         0
# codigo_postal         0
# dtype: int64
